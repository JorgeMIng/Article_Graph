# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("http://yordi111nas.synology.me:3030/energy/query")
sparql.setReturnFormat(JSON)


# wdt:P31 (instance_of)
sparql.setQuery(f"""
    SELECT * WHERE {{
  # ?sub ?pred ?obj .
    }}
""")
result=None
query_res=sparql.query().convert()

# %%
query_res
# Out:
# {'head': {'vars': ['sub', 'pred', 'obj']},
#  'results': {'bindings': [{'sub': {'type': 'uri',
#      'value': 'http://smartcity.group04.es/resource/District/12'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'obj': {'type': 'uri',
#      'value': 'http://smartcity.group04.es/ontology/EnergyConsumption#District'}},
#    {'sub': {'type': 'uri',
#      'value': 'http://smartcity.group04.es/resource/District/12'},
#     'pred': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'},
#     'obj': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#      'value': 'https://www.wikidata.org/entity/Q953368'}},
#    {'sub': {'type': 'uri',
#      'value': 'http://smartcity.group04.es/resource/District/12'},
#     'pred': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'obj': {'type': 'literal', 'value': 'Usera'}},
#    {'sub': {'type': 'uri',
# ...
